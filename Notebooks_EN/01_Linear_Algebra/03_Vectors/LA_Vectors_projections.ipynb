# %% [markdown]
# <a href="https://colab.research.google.com/github/Ruslan05001/Math-2024-25-Winter/blob/main/Notebooks_EN/01_Linear_Algebra/03_Vectors/LA_Vectors_projections.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vectors - Projections and Divisions
#
#
# ## Projecting a Vector onto Another Vector
#
# Projecting vector $\mathbf{a}$ onto axis $\mathbf{b}$ involves finding the component of vector $\mathbf{a}$ along the direction of $\mathbf{b}$.
#
# Projection of $\mathbf{a}$ onto $\mathbf{b}$:
#
# $$
# \text{Proj}_{\mathbf{b}} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{b}}{|\mathbf{b}|^2} \mathbf{b}
# $$
#
#
# ## Projecting a Vector onto Axes
#
# Projecting vector $\mathbf{a}$ onto an axis involves finding the component of vector $\mathbf{a}$ along that axis.
#
# Projection of $\mathbf{a}$ onto the $OX$ axis:
#
# $$
# \text{Proj}_{OX} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{i}}{|\mathbf{i}|^2} \mathbf{i} = \frac{\mathbf{a} \cdot \mathbf{i}}{1} \mathbf{i} = (\mathbf{a} \cdot \mathbf{i}) \mathbf{i}
# $$
#
# Projection of $\mathbf{a}$ onto the $OY$ axis:
#
# $$
# \text{Proj}_{OY} \mathbf{a} = \frac{\mathbf{a} \cdot \mathbf{j}}{|\mathbf{j}|^2} \mathbf{j} = \frac{\mathbf{a} \cdot \mathbf{j}}{1} \mathbf{j} = (\mathbf{a} \cdot \mathbf{j}) \mathbf{j}
# $$
#
# Recall that $\mathbf{i} = (1, 0)$ and $\mathbf{j} = (0, 1)$ are unit vectors along the $OX$ and $OY$ axes.
#
#
# ## Dividing a Line Segment in a Given Ratio
#
# A line segment is defined by two points in space.
#
# Line segments and vectors are closely related because a line segment connecting two points can be treated as a vector directed from one point to another.
#
# If point \( P \) divides the line segment connecting points $A(x_1, y_1)$ and $B(x_2, y_2)$ in the ratio $m:n$, then the coordinates of point $P$ can be found using the formula:
#
# $$
# P = \left(\frac{n \times x_2 + m \times x_1}{m+n}, \frac{n \times y_2 + m \times y_1}{m+n}\right)
# $$
#
# **Example:**
#
# Given a line segment connecting points $A(1, 2)$ and $B(3, 8)$, find point $P$ that divides the segment in the ratio 2:3.
#
# Coordinates of point $P$:
# $$
# P = \left(\frac{2 \times 3 + 3 \times 1}{2+3}, \frac{2 \times 8 + 3 \times 2}{2+3}\right) = \left(\frac{9}{5}, \frac{22}{5}\right)
# $$

# %%
import matplotlib.pyplot as plt
import math

# Coordinates of points A and B
A = (1, 2)
B = (3, 8)

# Ratio m:n
m, n = 2, 3

# Calculate coordinates of point P that divides the segment in the ratio 2:3
P_x = (n * A[0] + m * B[0]) / (m + n)
P_y = (n * A[1] + m * B[1]) / (m + n)
P = (P_x, P_y)

# Plotting the graph
plt.figure(figsize=(6, 6))

# Plotting line segment AB
plt.plot([A[0], B[0]], [A[1], B[1]], 'k--', label='Line Segment AB')

# Marking points A, B, and P
plt.scatter(*A, color='blue', label='A(1, 2)')
plt.scatter(*B, color='red', label='B(3, 8)')
plt.scatter(*P, color='green', label=f'P({P[0]:.2f}, {P[1]:.2f})')

# Point labels
plt.text(A[0]-0.2, A[1], 'A(1, 2)', fontsize=12, color='blue')
plt.text(B[0]+0.1, B[1], 'B(3, 8)', fontsize=12, color='red')
plt.text(P[0]+0.1, P[1], f'P({P[0]:.2f}, {P[1]:.2f})', fontsize=12, color='green')

# Adding grid and axis labels
plt.grid(True)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Dividing a Line Segment in the Ratio 2:3')
plt.legend()

# Displaying the graph
plt.show()

# %% [raw]
# ---

# %% [markdown]
# ## Student Exercises
#
# - Divide the line segment connecting points $A(-1, 2)$ and $B(3, -2)$ in the ratio $1:3$. Illustrate the result on a graph.
#
# - Project vector $\mathbf{a} = (3, 4)$ onto the $OX$ and $OY$ axes. Illustrate the result on a graph.
#
# - Project vector $\mathbf{a} = (2,3)$ onto vector $\mathbf{b} = (1, 1)$. Illustrate the result on a graph.
#
# - Project vector $\mathbf{b} = (1, 1)$ onto vector $\mathbf{a} = (2, 3)$. Illustrate the result on a graph.

# %%
import matplotlib.pyplot as plt

# Coordinates of points A, B and the dividing point
A = (-1, 2)
B = (3, -2)
P = (0, 1)  # Point dividing the segment in the ratio 1:3

# Plot the points
plt.plot([A[0], B[0]], [A[1], B[1]], 'b-', label='Line segment AB')
plt.plot(A[0], A[1], 'ro', label='Point A (-1, 2)')
plt.plot(B[0], B[1], 'go', label='Point B (3, -2)')
plt.plot(P[0], P[1], 'mo', label='Point P (0, 1)')

# Annotate the points
plt.text(A[0], A[1], 'A (-1, 2)', fontsize=12, ha='right')
plt.text(B[0], B[1], 'B (3, -2)', fontsize=12, ha='right')
plt.text(P[0], P[1], 'P (0, 1)', fontsize=12, ha='left')

# Set graph limits
plt.xlim(-2, 4)
plt.ylim(-3, 3)

# Label axes
plt.xlabel('x')
plt.ylabel('y')

# Display the grid and the legend
plt.grid(True)
plt.legend()

# Show the plot
plt.title('Division of Line Segment AB in the Ratio 1:3')
plt.show()

# %%
import matplotlib.pyplot as plt

# Coordinates of the vector and projections
a = (3, 4)
a_ox = (3, 0)
a_oy = (0, 4)

# Plot the vectors
plt.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='blue', label=r'$\mathbf{a} = (3, 4)$')
plt.quiver(0, 0, a_ox[0], a_ox[1], angles='xy', scale_units='xy', scale=1, color='red', label=r'$\mathbf{a}_{OX} = (3, 0)$')
plt.quiver(0, 0, a_oy[0], a_oy[1], angles='xy', scale_units='xy', scale=1, color='green', label=r'$\mathbf{a}_{OY} = (0, 4)$')

# Mark the points
plt.plot(a[0], a[1], 'bo')  # Point for vector a
plt.plot(a_ox[0], a_ox[1], 'ro')  # Point for projection onto OX
plt.plot(a_oy[0], a_oy[1], 'go')  # Point for projection onto OY

# Set the graph limits
plt.xlim(0, 4)
plt.ylim(0, 5)

# Label axes
plt.xlabel('x')
plt.ylabel('y')

# Display the grid and the legend
plt.grid(True)
plt.legend()

# Show the plot
plt.title('Projection of Vector a onto OX and OY Axes')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Coordinates of vectors a and b
a = np.array([2, 3])
b = np.array([1, 1])

# Projection of a onto b
proj_ab = (np.dot(a, b) / np.dot(b, b)) * b

# Create the plot
plt.figure()

# Plot vector a
plt.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='blue', label=r'$\mathbf{a} = (2, 3)$')

# Plot vector b
plt.quiver(0, 0, b[0], b[1], angles='xy', scale_units='xy', scale=1, color='green', label=r'$\mathbf{b} = (1, 1)$')

# Plot the projection of a onto b
plt.quiver(0, 0, proj_ab[0], proj_ab[1], angles='xy', scale_units='xy', scale=1, color='red', label=r'$\text{proj}_{\mathbf{b}} \mathbf{a}$')

# Mark the points
plt.plot(a[0], a[1], 'bo')  # Point for vector a
plt.plot(proj_ab[0], proj_ab[1], 'ro')  # Point for the projection of a onto b

# Set the graph limits
plt.xlim(0, 3)
plt.ylim(0, 4)

# Label axes
plt.xlabel('x')
plt.ylabel('y')

# Display the grid and the legend
plt.grid(True)
plt.legend()

# Show the plot
plt.title('Projection of Vector a onto Vector b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Coordinates of vectors a and b
a = np.array([2, 3])
b = np.array([1, 1])

# Projection of b onto a
proj_ab = (np.dot(b, a) / np.dot(a, a)) * a

# Create the plot
plt.figure()

# Plot vector b
plt.quiver(0, 0, b[0], b[1], angles='xy', scale_units='xy', scale=1, color='blue', label=r'$\mathbf{b} = (1, 1)$')

# Plot vector a
plt.quiver(0, 0, a[0], a[1], angles='xy', scale_units='xy', scale=1, color='green', label=r'$\mathbf{a} = (2, 3)$')

# Plot the projection of b onto a
plt.quiver(0, 0, proj_ab[0], proj_ab[1], angles='xy', scale_units='xy', scale=1, color='red', label=r'$\text{proj}_{\mathbf{a}} \mathbf{b}$')

# Mark the points
plt.plot(b[0], b[1], 'bo')  # Point for vector b
plt.plot(proj_ab[0], proj_ab[1], 'ro')  # Point for the projection of b onto a

# Set the graph limits
plt.xlim(0, 3)
plt.ylim(0, 4)

# Label axes
plt.xlabel('x')
plt.ylabel('y')

# Display the grid and the legend
plt.grid(True)
plt.legend()

# Show the plot
plt.title('Projection of Vector b onto Vector a')
plt.show()
